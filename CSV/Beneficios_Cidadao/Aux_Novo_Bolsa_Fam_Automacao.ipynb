# %%
pip install selenium pandas openpyxl minio webdriver-manager

# %%
import os
import time
import logging
import zipfile
import tempfile
from io import BytesIO
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from minio import Minio
from pathlib import Path

# Configuração de logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Obtém o diretório de downloads padrão do usuário
if os.name == 'nt':  # Windows
    download_path = os.path.join(os.environ['USERPROFILE'], 'Downloads')
else:  # Unix-based (Linux/Mac)
    download_path = os.path.join(os.environ['HOME'], 'Downloads')

# Configuração do MinIO
minio_client = Minio(
    "localhost:9000", 
    access_key="minioadmin",
    secret_key="minioadmin",
    secure=False
)
bucket_name = "aux-novo-bolsa-fam"

# Verifica se o bucket existe e cria se não existir
if not minio_client.bucket_exists(bucket_name):
    logging.info(f"Criando bucket: {bucket_name}")
    minio_client.make_bucket(bucket_name)

# Configuração do Chrome
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--allow-running-insecure-content")
chrome_options.add_argument("--unsafely-treat-insecure-origin-as-secure=https://portaldatransparencia.gov.br/download-de-dados/novo-bolsa-familia")
chrome_options.add_experimental_option("prefs", {"download.default_directory": download_path})

# Usando o ChromeDriverManager para garantir que o ChromeDriver esteja disponível
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

try:
    # Acessar site
    logging.info("Acessando o site do Portal de Transparência...")
    driver.get('https://portaldatransparencia.gov.br/download-de-dados/novo-bolsa-familia')

    # Fechar o modal de cookies, se presente
    try:
        time.sleep(2)
        cookie_button = driver.find_element(By.XPATH, '/html/body/div[5]/div/div/div/div[2]/div/button[3]')
        cookie_button.click()
        logging.info("Cookie modal fechado com sucesso.")
    except Exception as e:
        logging.warning("Modal de cookies não encontrado ou erro ao clicar: " + str(e))
    
    # Selecionar ano
    logging.info("Selecionando Ano...")
    select_element_ano = driver.find_element(By.XPATH, '/html/body/main/div[2]/div/div/div[3]/select')
    select_ano = Select(select_element_ano)
    options_ano = select_ano.options

    for option_ano in options_ano:
        ano_value = option_ano.get_attribute('value')
        select_ano.select_by_value(ano_value)
        logging.info(f"Ano selecionado: {option_ano.text}")
        time.sleep(1)

        # Selecionar mês para o ano atual
        select_element_mes = driver.find_element(By.XPATH, '/html/body/main/div[2]/div/div/div[4]/select')
        select_mes = Select(select_element_mes)
        options_mes = select_mes.options

        for option_mes in options_mes:
            select_mes.select_by_value(option_mes.get_attribute('value'))
            logging.info(f"Selecionado: {option_mes.text}/{option_ano.text}")
            time.sleep(1)
            
            # Iniciar Download
            logging.info("Iniciando Download...")
            botao = driver.find_element(By.XPATH, "//button[text()='Baixar']")
            botao.click()
            
            # Aguardar até o arquivo de download completar
            download_in_progress = True
            while download_in_progress:
                download_in_progress = not any(fname.endswith("_NovoBolsaFamilia.zip") for fname in os.listdir(download_path))
                logging.info("Aguardando a conclusão do download...")      
                time.sleep(5)

            # Processar arquivos baixados (ZIP)
            downloaded_files = [f for f in os.listdir(download_path) if f.endswith("_NovoBolsaFamilia.zip")]
            for zip_file_name in downloaded_files:
                zip_file_path = os.path.join(download_path, zip_file_name)

                with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
                    for file_name in zip_ref.namelist():
                        if file_name.endswith('.csv'):
                            with zip_ref.open(file_name) as csv_file:
                                # Criar um arquivo temporário no disco
                                with tempfile.TemporaryFile() as temp_file:
                                    temp_file.write(csv_file.read())  # Escreve dados no arquivo temporário
                                    
                                    # Verifica se o arquivo não está vazio
                                    file_size = temp_file.tell()
                                    if file_size > 0:
                                        temp_file.seek(0)  # Retorna ao início para leitura e upload

                                        # Upload do arquivo CSV para o MinIO
                                        logging.info(f"Enviando o arquivo CSV para o bucket {bucket_name} no MinIO...")
                                        minio_client.put_object(
                                            bucket_name,
                                            file_name,
                                            temp_file,
                                            file_size,
                                            content_type='text/csv'
                                        )
                                        logging.info(f"Arquivo {file_name} enviado para o MinIO com sucesso.")
                                    else:
                                        logging.warning(f"O arquivo {file_name} está vazio e não será enviado.")
                
                # Remover o arquivo ZIP local após o upload
                os.remove(zip_file_path)
                logging.info(f"Arquivo ZIP {zip_file_name} removido com sucesso.")

except Exception as e:
    logging.error(f"Ocorreu um erro: {e}")

finally:
    # Remove todos os arquivos .crdownload do diretório de downloads
    driver.quit()
    
    for fname in os.listdir(download_path):
        if fname.endswith(".crdownload"):
            os.remove(os.path.join(download_path, fname))
            logging.info(f"Arquivo temporário {fname} removido com sucesso.")
# Out:
# 2024-11-04 13:30:32,497 - INFO - Criando bucket: aux-novo-bolsa-fam
# 2024-11-04 13:30:32,524 - INFO - ====== WebDriver manager ======
# 2024-11-04 13:30:35,393 - INFO - Get LATEST chromedriver version for google-chrome
# 2024-11-04 13:30:36,393 - INFO - Get LATEST chromedriver version for google-chrome
# 2024-11-04 13:30:37,143 - INFO - Driver [C:\Users\pedro\.wdm\drivers\chromedriver\win64\130.0.6723.91\chromedriver-win32/chromedriver.exe] found in cache
# 2024-11-04 13:30:38,626 - INFO - Acessando o site do Portal de Transparência...
# 2024-11-04 13:30:42,764 - INFO - Cookie modal fechado com sucesso.
# 2024-11-04 13:30:42,764 - INFO - Selecionando Ano...
# 2024-11-04 13:30:42,914 - INFO - Ano selecionado: 2024
# 2024-11-04 13:30:44,023 - INFO - Selecionado: JANEIRO/2024
# 2024-11-04 13:30:45,025 - INFO - Iniciando Download...
# 2024-11-04 13:30:50,313 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:30:55,316 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:31:00,319 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:31:05,323 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:31:10,328 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:31:15,330 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:31:20,334 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:31:25,337 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:31:30,339 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:31:35,342 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:31:40,345 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:31:45,348 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:31:50,351 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:31:55,353 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:32:00,356 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:32:05,359 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:32:27,843 - INFO - Enviando o arquivo CSV para o bucket aux-novo-bolsa-fam no MinIO...
# 2024-11-04 13:32:53,256 - INFO - Arquivo 202401_NovoBolsaFamilia.csv enviado para o MinIO com sucesso.
# 2024-11-04 13:32:53,648 - INFO - Arquivo ZIP 202401_NovoBolsaFamilia.zip removido com sucesso.
# 2024-11-04 13:32:53,843 - INFO - Selecionado: FEVEREIRO/2024
# 2024-11-04 13:32:54,853 - INFO - Iniciando Download...
# 2024-11-04 13:32:55,421 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:33:00,424 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:33:05,426 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:33:10,429 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:33:15,431 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:33:20,434 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:33:25,436 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:33:30,449 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:33:35,457 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:33:40,465 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:33:45,471 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:33:50,475 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:33:55,477 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:34:00,481 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:34:34,350 - INFO - Enviando o arquivo CSV para o bucket aux-novo-bolsa-fam no MinIO...
# 2024-11-04 13:35:27,595 - INFO - Arquivo 202402_NovoBolsaFamilia.csv enviado para o MinIO com sucesso.
# 2024-11-04 13:35:28,556 - INFO - Arquivo ZIP 202402_NovoBolsaFamilia.zip removido com sucesso.
# 2024-11-04 13:35:28,877 - INFO - Selecionado: MARÇO/2024
# 2024-11-04 13:35:29,882 - INFO - Iniciando Download...
# 2024-11-04 13:35:31,626 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:35:36,632 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:35:41,645 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:35:46,648 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:35:51,653 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:35:56,658 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:36:01,663 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:36:06,666 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:36:11,674 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:36:16,677 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:36:21,694 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:36:26,697 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:36:31,701 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:37:04,641 - INFO - Enviando o arquivo CSV para o bucket aux-novo-bolsa-fam no MinIO...
# 2024-11-04 13:37:50,842 - INFO - Arquivo 202403_NovoBolsaFamilia.csv enviado para o MinIO com sucesso.
# 2024-11-04 13:37:51,543 - INFO - Arquivo ZIP 202403_NovoBolsaFamilia.zip removido com sucesso.
# 2024-11-04 13:37:51,900 - INFO - Selecionado: ABRIL/2024
# 2024-11-04 13:37:52,913 - INFO - Iniciando Download...
# 2024-11-04 13:37:56,461 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:38:01,466 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:38:06,471 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:38:11,477 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:38:16,481 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:38:21,502 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:38:26,505 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:38:31,506 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:38:36,525 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:38:41,541 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:38:46,545 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:38:51,549 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:38:56,553 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:39:01,561 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:39:06,585 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:39:47,993 - INFO - Enviando o arquivo CSV para o bucket aux-novo-bolsa-fam no MinIO...
# 2024-11-04 13:40:34,880 - INFO - Arquivo 202404_NovoBolsaFamilia.csv enviado para o MinIO com sucesso.
# 2024-11-04 13:40:35,366 - INFO - Arquivo ZIP 202404_NovoBolsaFamilia.zip removido com sucesso.
# 2024-11-04 13:40:35,765 - INFO - Selecionado: MAIO/2024
# 2024-11-04 13:40:36,780 - INFO - Iniciando Download...
# 2024-11-04 13:40:37,553 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:40:42,567 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:40:47,572 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:40:52,591 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:40:57,594 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:41:02,611 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:41:07,617 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:41:12,624 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:41:17,632 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:41:22,649 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:41:27,654 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:41:32,657 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:41:37,659 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:41:42,663 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:41:47,667 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:42:17,226 - INFO - Enviando o arquivo CSV para o bucket aux-novo-bolsa-fam no MinIO...
# 2024-11-04 13:43:02,614 - INFO - Arquivo 202405_NovoBolsaFamilia.csv enviado para o MinIO com sucesso.
# 2024-11-04 13:43:03,474 - INFO - Arquivo ZIP 202405_NovoBolsaFamilia.zip removido com sucesso.
# 2024-11-04 13:43:03,929 - INFO - Selecionado: JUNHO/2024
# 2024-11-04 13:43:04,943 - INFO - Iniciando Download...
# 2024-11-04 13:43:05,397 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:43:10,404 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:43:15,407 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:43:20,422 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:43:25,434 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:43:30,449 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:43:35,465 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:43:40,467 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:43:45,471 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:43:50,483 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:43:55,486 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:44:00,496 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:44:05,498 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:44:10,503 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:44:48,159 - INFO - Enviando o arquivo CSV para o bucket aux-novo-bolsa-fam no MinIO...
# 2024-11-04 13:45:26,114 - INFO - Arquivo 202406_NovoBolsaFamilia.csv enviado para o MinIO com sucesso.
# 2024-11-04 13:45:26,557 - INFO - Arquivo ZIP 202406_NovoBolsaFamilia.zip removido com sucesso.
# 2024-11-04 13:45:26,820 - INFO - Ano selecionado: 2023
# 2024-11-04 13:45:28,093 - INFO - Selecionado: MARÇO/2023
# 2024-11-04 13:45:29,097 - INFO - Iniciando Download...
# 2024-11-04 13:45:30,884 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:45:35,895 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:45:40,902 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:45:45,908 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:45:50,912 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:45:55,918 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:46:00,932 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:46:05,940 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:46:10,949 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:46:15,955 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:46:20,965 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:46:25,972 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:46:30,974 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:46:35,982 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:46:40,988 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:46:45,992 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:47:11,914 - INFO - Enviando o arquivo CSV para o bucket aux-novo-bolsa-fam no MinIO...
# 2024-11-04 13:47:46,438 - INFO - Arquivo 202303_NovoBolsaFamilia.csv enviado para o MinIO com sucesso.
# 2024-11-04 13:47:47,211 - INFO - Arquivo ZIP 202303_NovoBolsaFamilia.zip removido com sucesso.
# 2024-11-04 13:47:47,551 - INFO - Selecionado: ABRIL/2023
# 2024-11-04 13:47:48,555 - INFO - Iniciando Download...
# 2024-11-04 13:47:49,597 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:47:54,602 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:47:59,615 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:48:04,618 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:48:09,632 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:48:14,652 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:48:19,662 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:48:24,675 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:48:29,693 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:48:34,697 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:48:39,699 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:48:44,704 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:48:49,708 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:48:54,712 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:48:59,714 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:49:37,304 - INFO - Enviando o arquivo CSV para o bucket aux-novo-bolsa-fam no MinIO...
# 2024-11-04 13:50:25,734 - INFO - Arquivo 202304_NovoBolsaFamilia.csv enviado para o MinIO com sucesso.
# 2024-11-04 13:50:26,506 - INFO - Arquivo ZIP 202304_NovoBolsaFamilia.zip removido com sucesso.
# 2024-11-04 13:50:26,828 - INFO - Selecionado: MAIO/2023
# 2024-11-04 13:50:27,833 - INFO - Iniciando Download...
# 2024-11-04 13:50:30,257 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:50:35,272 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:50:40,276 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:50:45,294 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:50:50,296 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:50:55,299 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:51:00,314 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:51:05,334 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:51:10,339 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:51:15,342 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:51:20,347 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:51:25,352 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:51:30,356 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:51:35,363 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:52:07,881 - INFO - Enviando o arquivo CSV para o bucket aux-novo-bolsa-fam no MinIO...
# 2024-11-04 13:52:29,701 - INFO - Arquivo 202305_NovoBolsaFamilia.csv enviado para o MinIO com sucesso.
# 2024-11-04 13:52:30,129 - INFO - Arquivo ZIP 202305_NovoBolsaFamilia.zip removido com sucesso.
# 2024-11-04 13:52:30,362 - INFO - Selecionado: JUNHO/2023
# 2024-11-04 13:52:31,365 - INFO - Iniciando Download...
# 2024-11-04 13:52:31,734 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:52:36,741 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:52:41,748 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:52:46,750 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:52:51,763 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:52:56,765 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:53:01,767 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:53:06,779 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:53:11,782 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:53:16,792 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:53:21,798 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:53:26,802 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:53:31,807 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:53:36,812 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:54:12,168 - INFO - Enviando o arquivo CSV para o bucket aux-novo-bolsa-fam no MinIO...
# 2024-11-04 13:55:00,102 - INFO - Arquivo 202306_NovoBolsaFamilia.csv enviado para o MinIO com sucesso.
# 2024-11-04 13:55:00,881 - INFO - Arquivo ZIP 202306_NovoBolsaFamilia.zip removido com sucesso.
# 2024-11-04 13:55:01,262 - INFO - Selecionado: JULHO/2023
# 2024-11-04 13:55:02,275 - INFO - Iniciando Download...
# 2024-11-04 13:55:03,137 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:55:08,145 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:55:13,148 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:55:18,164 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:55:23,166 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:55:28,168 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:55:33,183 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:55:38,190 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:55:43,208 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:55:48,211 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:55:53,217 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:55:58,222 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:56:03,227 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:56:08,232 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:56:42,270 - INFO - Enviando o arquivo CSV para o bucket aux-novo-bolsa-fam no MinIO...
# 2024-11-04 13:57:17,202 - INFO - Arquivo 202307_NovoBolsaFamilia.csv enviado para o MinIO com sucesso.
# 2024-11-04 13:57:17,543 - INFO - Arquivo ZIP 202307_NovoBolsaFamilia.zip removido com sucesso.
# 2024-11-04 13:57:17,825 - INFO - Selecionado: AGOSTO/2023
# 2024-11-04 13:57:18,847 - INFO - Iniciando Download...
# 2024-11-04 13:57:19,256 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:57:24,269 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:57:29,272 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:57:34,274 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:57:39,277 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:57:44,280 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:57:49,290 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:57:54,294 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:57:59,296 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:58:04,298 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:58:09,302 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:58:14,305 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:58:19,314 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:58:24,317 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:58:29,319 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:58:34,327 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:58:39,330 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:58:44,333 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:58:49,337 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:58:54,340 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:58:59,341 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:59:21,794 - INFO - Enviando o arquivo CSV para o bucket aux-novo-bolsa-fam no MinIO...
# 2024-11-04 13:59:41,751 - INFO - Arquivo 202308_NovoBolsaFamilia.csv enviado para o MinIO com sucesso.
# 2024-11-04 13:59:42,191 - INFO - Arquivo ZIP 202308_NovoBolsaFamilia.zip removido com sucesso.
# 2024-11-04 13:59:42,431 - INFO - Selecionado: SETEMBRO/2023
# 2024-11-04 13:59:43,437 - INFO - Iniciando Download...
# 2024-11-04 13:59:45,146 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:59:50,148 - INFO - Aguardando a conclusão do download...
# 2024-11-04 13:59:55,156 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:00:00,159 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:00:05,161 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:00:10,175 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:00:15,185 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:00:20,186 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:00:25,189 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:00:30,193 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:00:35,197 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:00:40,200 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:00:45,204 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:00:50,208 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:00:55,211 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:01:00,217 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:01:05,224 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:01:10,229 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:01:15,236 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:01:20,239 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:01:25,242 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:01:30,247 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:01:51,259 - INFO - Enviando o arquivo CSV para o bucket aux-novo-bolsa-fam no MinIO...
# 2024-11-04 14:02:10,743 - INFO - Arquivo 202309_NovoBolsaFamilia.csv enviado para o MinIO com sucesso.
# 2024-11-04 14:02:11,213 - INFO - Arquivo ZIP 202309_NovoBolsaFamilia.zip removido com sucesso.
# 2024-11-04 14:02:11,452 - INFO - Selecionado: OUTUBRO/2023
# 2024-11-04 14:02:12,473 - INFO - Iniciando Download...
# 2024-11-04 14:02:15,075 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:02:20,081 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:02:25,083 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:02:30,086 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:02:35,088 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:02:40,092 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:02:45,097 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:02:50,099 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:02:55,103 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:03:00,105 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:03:05,108 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:03:10,110 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:03:15,116 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:03:36,802 - INFO - Enviando o arquivo CSV para o bucket aux-novo-bolsa-fam no MinIO...
# 2024-11-04 14:03:54,444 - INFO - Arquivo 202310_NovoBolsaFamilia.csv enviado para o MinIO com sucesso.
# 2024-11-04 14:03:54,906 - INFO - Arquivo ZIP 202310_NovoBolsaFamilia.zip removido com sucesso.
# 2024-11-04 14:03:55,106 - INFO - Selecionado: NOVEMBRO/2023
# 2024-11-04 14:03:56,121 - INFO - Iniciando Download...
# 2024-11-04 14:03:56,678 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:04:01,682 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:04:06,686 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:04:11,702 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:04:16,705 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:04:21,707 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:04:26,711 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:04:31,714 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:04:36,716 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:04:41,718 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:04:46,721 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:04:51,723 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:04:56,736 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:05:01,739 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:05:23,722 - INFO - Enviando o arquivo CSV para o bucket aux-novo-bolsa-fam no MinIO...
# 2024-11-04 14:05:42,244 - INFO - Arquivo 202311_NovoBolsaFamilia.csv enviado para o MinIO com sucesso.
# 2024-11-04 14:05:42,705 - INFO - Arquivo ZIP 202311_NovoBolsaFamilia.zip removido com sucesso.
# 2024-11-04 14:05:42,815 - INFO - Selecionado: DEZEMBRO/2023
# 2024-11-04 14:05:43,818 - INFO - Iniciando Download...
# 2024-11-04 14:05:44,066 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:05:49,077 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:05:54,080 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:05:59,087 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:06:04,089 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:06:09,092 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:06:14,094 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:06:19,097 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:06:24,100 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:06:29,103 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:06:34,106 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:06:39,108 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:06:44,111 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:06:49,114 - INFO - Aguardando a conclusão do download...
# 2024-11-04 14:07:06,662 - INFO - Enviando o arquivo CSV para o bucket aux-novo-bolsa-fam no MinIO...
# 2024-11-04 14:07:24,562 - INFO - Arquivo 202312_NovoBolsaFamilia.csv enviado para o MinIO com sucesso.
# 2024-11-04 14:07:24,821 - INFO - Arquivo ZIP 202312_NovoBolsaFamilia.zip removido com sucesso.
